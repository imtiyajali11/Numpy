# %% [markdown]
# # 3rd lecture

# %%
import numpy as np

# %%
# Topic Name: measure of central tendency.
# go for mean, median mode, and average

a = np.random.randint(1,10,10)
a
# Out:
# array([9, 4, 3, 6, 9, 2, 7, 8, 8, 8])

# %%
# mean

mean = sum(a)/len(a)
mean
# Out:
# np.float64(4.3)

# %%
np.mean(a)
# Out:
# np.float64(4.3)

# %%
# median

np.median(a)
# Out:
# np.float64(4.0)

# %%
b =sorted(a)
b
# Out:
# [np.int64(1),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(4),
#  np.int64(4),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9)]

# %%
me = (4+4)/2
me
# Out:
# 4.0

# %%
# mode
# most occuring value


# np.mode(a)

d = {}

for i in a:
    if i in d:
        d[i] += 1

    else:
        d[i] = 1

d
# Out:
# {np.int64(9): 2,
#  np.int64(4): 1,
#  np.int64(3): 1,
#  np.int64(6): 1,
#  np.int64(2): 1,
#  np.int64(7): 1,
#  np.int64(8): 3}

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
