# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# - avg salary = 30K
# - phone = 50K
#
# - how is the chances of the sucess.

# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("https://gist.githubusercontent.com/danielmoralesp/650bf482113d05e75f283607637ea11b/raw/71b4ebd2472767662ffbd23fa35ec7ad6f5f92a6/heights.csv")

# %%
df.head()
# Out:
#    height  weight
# 0   65.78  112.99
# 1   71.52  136.49
# 2   69.40  153.03
# 3   68.22  142.34
# 4   67.79  144.30

# %%
df.shape
# Out:
# (200, 2)

# %%
df.describe()
# Out:
#            height      weight
# count  200.000000  200.000000
# mean    67.949800  127.221950
# std      1.940363   11.960959
# min     63.430000   97.900000
# 25%     66.522500  119.895000
# 50%     67.935000  127.875000
# 75%     69.202500  136.097500
# max     73.900000  158.960000

# %%
# graph
df['height'].value_counts(normalize= True).plot.bar()
# Out:
# <Axes: xlabel='height'>

# %%
df.plot.bar(x = 'height', y = 'weight')
# Out:
# <Axes: xlabel='height'>

# %%
sample = df.sample(37)

# %%
sample.describe()
# Out:
#           height      weight
# count  37.000000   37.000000
# mean   67.799730  124.444595
# std     2.078965   11.955469
# min    64.290000  102.090000
# 25%    66.010000  118.890000
# 50%    67.900000  124.800000
# 75%    69.430000  130.700000
# max    72.020000  155.380000

# %%
import numpy as np

# %%
# prove that the mean of the population and sample are equal


sample_mean = sample['weight'].mean()
n = len(sample)
population_mean = df['weight'].mean()
population_std= df['weight'].std()

# %%
sample_mean, n, population_mean, population_std
# Out:
# (np.float64(124.44459459459456),
#  37,
#  np.float64(127.22194999999999),
#  11.960959176403792)

# %%
ztest = (sample_mean/population_mean)/(population_std/(np.sqrt(n)))
ztest
# Out:
# np.float64(0.4974493219115572)

# %%
# p =  0.05

# 95% confidence

# %%
zcritical = -1.9
